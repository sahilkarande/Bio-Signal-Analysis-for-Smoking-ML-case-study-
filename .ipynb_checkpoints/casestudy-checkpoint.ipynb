# %% [markdown]
# # Bio Signal for Smoking

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
from numpy import random
import pandas as pd
import os
from numpy.linalg import inv
import scipy
from scipy import stats
from scipy.stats import skew,kurtosis
import matplotlib
from matplotlib import pyplot as  plt
import seaborn as sns
# %matplotlib inline
from scipy.stats import binom
pd.set_option('Display.max_columns',None)
from scipy.stats import expon
from scipy.stats import norm
from scipy.stats import t
from scipy.stats import chisquare,chi2,chi2_contingency
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
from statsmodels.stats import proportion as ssp
from statsmodels.stats.proportion import proportions_ztest
from sklearn.model_selection import train_test_split
from statsmodels import discrete
from statsmodels.discrete import discrete_model
from statsmodels.discrete.discrete_model import MNLogit
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, LassoCV,Ridge,RidgeCV
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from statsmodels.discrete.discrete_model import NegativeBinomial as ngb
from statsmodels.miscmodels.ordinal_model import OrderedModel
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.metrics import roc_curve, auc, confusion_matrix

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('assets\smoking.csv')

# %% [markdown]
# ## Basic info about Dataset

# %%
df.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0              1.0            1.0             1.0     114.0        73.0
# 1              0.6            1.0             1.0     119.0        70.0
# 2              0.8            1.0             1.0     138.0        86.0
# 3              1.5            1.0             1.0     100.0        60.0
# 4              1.0            1.0             1.0     120.0        74.0
#
#    fasting blood sugar  Cholesterol  triglyceride   HDL    LDL  hemoglobin  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                     0
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
df.shape
# Out:
# (55692, 27)

# %%
df[['gender', 'oral', 'tartar']]
# Out:
#       gender oral tartar
# 0          F    Y      Y
# 1          F    Y      Y
# 2          M    Y      N
# 3          M    Y      Y
# 4          F    Y      N
# ...      ...  ...    ...
# 55687      F    Y      Y
# 55688      F    Y      Y
# 55689      F    Y      N
# 55690      M    Y      N
# 55691      M    Y      Y
#
# [55692 rows x 3 columns]

# %% [markdown]
# ## Binary Encoding

# %%
df['gender'] = df['gender'].map({'M': 1, 'F': 0})
df['oral'] = df['oral'].map({'Y': 1, 'N': 0})
df['tartar'] = df['tartar'].map({'Y': 1, 'N': 0})

# %%
df.dropna(inplace=True)
df[['gender','oral','tartar']]
# Out:
#        gender  oral  tartar
# 0           0     1       1
# 1           0     1       1
# 2           1     1       0
# 3           1     1       1
# 4           0     1       0
# ...       ...   ...     ...
# 55687       0     1       1
# 55688       0     1       1
# 55689       0     1       0
# 55690       1     1       0
# 55691       1     1       1
#
# [55692 rows x 3 columns]

# %%
df.head()
# Out:
#    ID  gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0       0   40         155          60       81.3             1.2
# 1   1       0   40         160          60       81.0             0.8
# 2   2       1   55         170          60       80.0             0.8
# 3   3       1   40         165          70       88.0             1.5
# 4   4       0   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0              1.0            1.0             1.0     114.0        73.0
# 1              0.6            1.0             1.0     119.0        70.0
# 2              0.8            1.0             1.0     138.0        86.0
# 3              1.5            1.0             1.0     100.0        60.0
# 4              1.0            1.0             1.0     120.0        74.0
#
#    fasting blood sugar  Cholesterol  triglyceride   HDL    LDL  hemoglobin  \
# ...

# %%
df.describe()
# Out:
#                  ID        gender           age    height(cm)    weight(kg)  \
# count  55692.000000  55692.000000  55692.000000  55692.000000  55692.000000
# mean   27845.500000      0.635657     44.182917    164.649321     65.864936
# std    16077.039933      0.481250     12.071418      9.194597     12.820306
# min        0.000000      0.000000     20.000000    130.000000     30.000000
# 25%    13922.750000      0.000000     40.000000    160.000000     55.000000
# 50%    27845.500000      1.000000     40.000000    165.000000     65.000000
# 75%    41768.250000      1.000000     55.000000    170.000000     75.000000
# max    55691.000000      1.000000     85.000000    190.000000    135.000000
#
#           waist(cm)  eyesight(left)  eyesight(right)  hearing(left)  \
# count  55692.000000    55692.000000     55692.000000   55692.000000
# mean      82.046418        1.012623         1.007443       1.025587
# std        9.274223        0.486873         0.485964       0.157902
# ...

# %% [markdown]
# ## EDA and Graph plotting

# %%
# Plotting the smoker and non-smoker 
# distribution in the given dataset

sns.countplot(x='smoking', data=df)
plt.title('Smoker\'s distribution')
# Out:
# Text(0.5, 1.0, "Smoker's distribution")

# %%
print("Percentage of smoker(1) vs non-smoker(1)\n",round(df['smoking'].value_counts(normalize=True)*100))
# Out:
# Percentage of smoker(1) vs non-smoker(1)
#  smoking
# 0    63.0
# 1    37.0
# Name: proportion, dtype: float64

# %% [markdown]
# There are total 63% of non-smokers and 37% of smokers in the given dataset

# %%
numerical = df.select_dtypes(include=['float64', 'int64']).columns.drop('smoking')

for col in numerical:
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# # Distributions Code

# %% [markdown]
# ### Distribution of Gender (0: Female, 1: Male)
# print("### Distribution of Gender:")
# print(df['gender'].value_counts().sort_index())
#
# ## Distribution of Age (Grouped: 10-20, 20-30, ...)
# print("\n### Distribution of Age:")
# print(pd.cut(df['age'], bins=np.arange(10, 100, 10), right=False).value_counts().sort_index())
#
# ## Distribution of Height (Grouped: 130-135, 135-140, ...)
# print("\n### Distribution of Height:")
# print(pd.cut(df['height(cm)'], bins=np.arange(130, 200, 5), right=False).value_counts().sort_index())
#
# ## Distribution of Weight (Grouped: 40-45, 45-50, ...)
# print("\n### Distribution of Weight:")
# print(pd.cut(df['weight(kg)'], bins=np.arange(40, 150, 5), right=False).value_counts().sort_index())
#
# ## Distribution of Waist
# print("\n### Distribution of Waist:")
# print(pd.cut(df['waist(cm)'], bins=np.arange(60, 130, 5), right=False).value_counts().sort_index())
#
# # Eyesight (Left)
# print("\n### Distribution of Eyesight (Left):")
# print(pd.cut(df['eyesight(left)'], bins=np.arange(0, 2.5, 0.2), right=False).value_counts().sort_index())
#
# # Eyesight (Right)
# print("\n### Distribution of Eyesight (Right):")
# print(pd.cut(df['eyesight(right)'], bins=np.arange(0, 2.5, 0.2), right=False).value_counts().sort_index())
#
# # Systolic BP
# print("\n### Distribution of Systolic BP:")
# print(pd.cut(df['systolic'], bins=np.arange(80, 200, 10), right=False).value_counts().sort_index())
#
# # Relaxation (Diastolic BP)
# print("\n### Distribution of Relaxation BP:")
# print(pd.cut(df['relaxation'], bins=np.arange(40, 120, 10), right=False).value_counts().sort_index())
#
# # Cholesterol
# print("\n### Distribution of Cholesterol:")
# print(pd.cut(df['cholesterol'], bins=np.arange(100, 350, 25), right=False).value_counts().sort_index())
#
# # Weight (Repeated field)
# # Skip or ensure 'weight' vs 'weight(kg)' consistency
#
# # Smoking status
# print("\n### Distribution of Smoking:")
# print(df['smoking'].value_counts().sort_index())
#
# # Distribution of Hearing (Left)
# print("\n### Distribution of Hearing (Left):")
# print(df['hearing(left)'].value_counts().sort_index())
#
# # Distribution of Hearing (Right)
# print("\n### Distribution of Hearing (Right):")
# print(df['hearing(right)'].value_counts().sort_index())
#
# # Distribution of Fasting Blood Sugar
# print("\n### Distribution of Fasting Blood Sugar:")
# print(pd.cut(df['fasting blood sugar'], bins=np.arange(50, 200, 10), right=False).value_counts().sort_index())
#
# # Distribution of Triglyceride
# print("\n### Distribution of Triglyceride:")
# print(pd.cut(df['triglyceride'], bins=np.arange(30, 400, 25), right=False).value_counts().sort_index())
#
# # Distribution of HDL
# print("\n### Distribution of HDL:")
# print(pd.cut(df['HDL'], bins=np.arange(10, 100, 10), right=False).value_counts().sort_index())
#
# # Distribution of LDL
# print("\n### Distribution of LDL:")
# print(pd.cut(df['LDL'], bins=np.arange(30, 300, 20), right=False).value_counts().sort_index())
#
# # Distribution of Hemoglobin
# print("\n### Distribution of Hemoglobin:")
# print(pd.cut(df['hemoglobin'], bins=np.arange(5, 20, 1), right=False).value_counts().sort_index())
#
# # Distribution of Urine Protein
# print("\n### Distribution of Urine Protein:")
# print(df['Urine protein'].value_counts().sort_index())
#
# # Distribution of Serum Creatinine
# print("\n### Distribution of Serum Creatinine:")
# print(pd.cut(df['serum creatinine'], bins=np.arange(0.1, 2.0, 0.1), right=False).value_counts().sort_index())
#
# # Distribution of AST
# print("\n### Distribution of AST:")
# print(pd.cut(df['AST'], bins=np.arange(0, 100, 10), right=False).value_counts().sort_index())
#
# # Distribution of ALT
# print("\n### Distribution of ALT:")
# print(pd.cut(df['ALT'], bins=np.arange(0, 100, 10), right=False).value_counts().sort_index())
#
# # Distribution of GTP
# print("\n### Distribution of GTP:")
# print(pd.cut(df['Gtp'], bins=np.arange(0, 200, 10), right=False).value_counts().sort_index())
#
# # Distribution of Oral
# print("\n### Distribution of Oral:")
# print(df['oral'].value_counts().sort_index())
#
# # Distribution of Dental Caries
# print("\n### Distribution of Dental Caries:")
# print(df['dental caries'].value_counts().sort_index())
#
# # Distribution of Tartar
# print("\n### Distribution of Tartar:")
# print(df['tartar'].value_counts().sort_index())

# %% [markdown]
# # Distributions Summary

# %% [markdown]
# ### Gender:
#
# * Around 35,400 males are present in the dataset.
# * Female count is approximately 20,200.
# * The dataset has a higher proportion of males, which could introduce slight gender bias.
#
# ---
#
# ### Age:
#
# * The highest concentration of individuals falls in the 40–50 age group (over 22,000).
# * Significant numbers also lie in the 30–40 and 50–60 brackets.
# * Very few individuals are over 70, and almost none below 20, indicating focus on adult population health.
#
# ---
#
# ### Height:
#
# * Most people have heights between 160 and 180 cm.
# * The 170–180 cm range has the maximum number of individuals.
# * Heights below 150 cm or above 190 cm are rare, making the distribution tight around the adult average.
#
# ---
#
# ### Weight:
#
# * Majority of the individuals weigh between 55 and 85 kg.
# * The 60–70 kg range shows the highest frequency.
# * Extremely low or high weights are uncommon, which indicates balanced health conditions in the dataset.
#
# ---
#
# ### Waist:
#
# * Waist measurements are mostly between 75 and 90 cm.
# * The peak is in the 80–85 cm range, followed closely by 75–80 cm and 85–90 cm.
# * Larger waist sizes above 100 cm are relatively less frequent.
#
# ---
#
# ### Eyesight (Left):
#
# * Most values are between 0.5 and 1.5.
# * The 1.0–1.5 range dominates the data, followed by 0.5–1.0.
# * Very few people have perfect or very poor eyesight based on this distribution.
#
# ---
#
# ### Eyesight (Right):
#
# * Majority fall in the 1.0–1.2 range.
# * The 0.8–1.0 and 1.4–1.6 ranges are also fairly common.
# * Lower or extreme ranges like 0.0–0.4 or above 2.0 are very rare.
#
# ---
#
# ### Systolic Blood Pressure:
#
# * Most people have systolic pressure between 100 and 140 mmHg.
# * The peak is in the 120–140 range, indicating a healthy to pre-hypertensive level for many.
# * Values beyond 160 are very limited.
#
# ---
#
# ### Relaxation (Diastolic BP):
#
# * Highest number of entries lie between 70 and 90 mmHg.
# * The 70–80 group shows maximum count, suggesting average diastolic health.
# * Very few entries lie below 50 or above 100.
#
# ---
#
# ### Cholesterol:
#
# * Most cholesterol values lie between 150 and 225.
# * The 175–200 group contains the largest number of individuals.
# * Very high cholesterol levels (275+) are rare, though they do exist.
#
# ---
#
# ### Smoking:
#
# * Non-smokers count around 35,200.
# * Smokers make up about 20,400 entries.
# * Non-smokers are the majority, but the number of smokers is still quite significant.
#
# ---
#
# ### Hearing (Left and Right):
#
# * Nearly all individuals have hearing level marked as 1.0.
# * Only about 1,400–1,500 entries show hearing issues (value 2.0), indicating mostly normal hearing in the population.
#
# ---
#
# ### Fasting Blood Sugar:
#
# * Most values range between 80 and 110.
# * The 90–100 group dominates, suggesting stable sugar levels in most individuals.
# * Elevated sugar levels (130+) are seen in fewer people, hinting at a smaller diabetic portion.
#
# ---
#
# ### Triglyceride:
#
# * Values mostly fall between 55 and 180.
# * Peak distribution lies in the 55–105 range, tapering off sharply above 200.
# * Extremely high values are rare.
#
# ---
#
# ### HDL:
#
# * Most people fall in the 40–70 HDL range.
# * A healthy distribution with the majority between 50 and 60.
# * Extremely low or high HDL values are uncommon.
#
# ---
#
# ### LDL:
#
# * Highest concentration is seen in the 110–130 and 90–110 groups.
# * Most people lie in the 70–150 range, which aligns with average health profiles.
# * Very high LDL (200+) is rare.
#
# ---
#
# ### Hemoglobin:
#
# * Values commonly range between 12 and 16.
# * Peak group is 15–16, followed by 14–15 and 13–14.
# * Extremely low hemoglobin (anemic levels) is rare but present.
#
# ---
#
# ### Urine Protein:
#
# * Most individuals have a urine protein level of 1.0.
# * Higher levels like 3.0 or more are rare and may indicate kidney or metabolic issues.
#
# ---
#
# ### Serum Creatinine:
#
# * Major distribution lies between 0.6 and 1.2.
# * Very high or low values are rare and might point to abnormal kidney function in a few cases.
#
# ---
#
# ### AST and ALT:
#
# * AST mostly ranges between 10 and 30.
# * ALT mostly lies between 10 and 40.
# * Spikes beyond 60 are rare and can indicate potential liver conditions.
#
# ---
#
# ### GTP:
#
# * Peak distribution lies between 10 and 30.
# * Very few people show levels above 100.
# * Majority of individuals fall in a healthy liver enzyme range.
#
# ---
#
# ### Oral, Dental Caries, and Tartar:
#
# * Most people had an oral checkup done.
# * About 11,800 individuals have dental caries, with the rest caries-free.
# * Roughly 30,900 have tartar issues, suggesting a possible hygiene trend.

# %%
# Compute and print correlation matrix
correlation_matrix = df.corr().round(2)
correlation_matrix
# Out:
#                        ID  gender   age  height(cm)  weight(kg)  waist(cm)  \
# ID                   1.00    0.01 -0.00        0.01        0.00       0.01
# gender               0.01    1.00 -0.29        0.74        0.57       0.42
# age                 -0.00   -0.29  1.00       -0.48       -0.32      -0.03
# height(cm)           0.01    0.74 -0.48        1.00        0.68       0.38
# weight(kg)           0.00    0.57 -0.32        0.68        1.00       0.82
# waist(cm)            0.01    0.42 -0.03        0.38        0.82       1.00
# eyesight(left)       0.01    0.13 -0.20        0.15        0.11       0.03
# eyesight(right)      0.00    0.13 -0.19        0.16        0.11       0.04
# hearing(left)        0.00   -0.01  0.20       -0.08       -0.05       0.02
# hearing(right)      -0.00   -0.01  0.21       -0.08       -0.05       0.02
# systolic             0.00    0.17  0.13        0.08        0.27       0.32
# ...

# %%
plt.figure(figsize=(17,15))
corr = df.corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Key Correlations with Smoking (Target Variable):
#
# * **Gender (0.51):** Strong positive correlation. Males are more likely to be smokers in this dataset.
# * **Hemoglobin (0.40):** Moderate positive correlation. Smokers tend to have slightly higher hemoglobin levels.
# * **Height (0.40):** Taller individuals show a moderate correlation with smoking, possibly linked to gender bias.
# * **Weight (0.30):** Slight positive correlation. Heavier individuals are slightly more likely to smoke.
# * **Triglyceride (0.25):** Mild positive correlation. Smokers may have higher triglyceride levels.
# * **GTP (0.24):** Gamma-GTP shows mild correlation, which aligns with its link to liver function often affected by smoking.
# * **Waist Circumference (0.23):** Weak positive correlation. Larger waist size may loosely associate with smoking.
# * **Serum Creatinine (0.22):** Weak correlation; could relate to kidney strain in smokers.
# * **ALT (0.10), AST (0.06):** Weak positive correlation; suggests mild liver enzyme elevations in smokers.
# * **Fasting Blood Sugar (0.10):** Weak correlation; may imply some metabolic effects.
# * **Tartar and Dental Caries (0.10 each):** Weak, but logical connection—smoking affects oral hygiene.
# * **Eyesight (left & right):** Very weak positive correlations (0.06 each).
# * **Age (-0.16):** Negative correlation. Younger individuals are more likely to be smokers.
# * **HDL (-0.18):** Negative correlation. Smokers tend to have lower "good" cholesterol.
# * **LDL (-0.05):** Weak negative correlation, possibly due to health impact moderation or treatment.

# %%
corr_target = corr["smoking"].sort_values(ascending=False)
print(corr_target)
# Out:
# smoking                1.000000
# gender                 0.510340
# hemoglobin             0.400678
# height(cm)             0.396675
# weight(kg)             0.302780
# triglyceride           0.251799
# Gtp                    0.236619
# waist(cm)              0.226259
# serum creatinine       0.216812
# relaxation             0.108309
# dental caries          0.103857
# fasting blood sugar    0.100279
# tartar                 0.098655
# ALT                    0.097338
# systolic               0.073109
# eyesight(right)        0.063017
# eyesight(left)         0.061204
# AST                    0.059253
# Urine protein          0.014267
# ID                     0.011476
# hearing(right)        -0.018855
# hearing(left)         -0.023209
# Cholesterol           -0.028548
# LDL                   -0.045220
# age                   -0.162557
# HDL                   -0.178470
# oral                        NaN
# Name: smoking, dtype: float64

# %% [markdown]
# ### Other Observations:
#
# * **Gender is strongly correlated with height (0.74)** and **hemoglobin (0.70)** — suggesting that these features are likely influenced by male dominance in the dataset.
# * **Height, weight, and waist** show moderate inter-correlation and also have positive links with smoking.
# * **Cholesterol, triglyceride, HDL, LDL** are all interrelated, with **HDL** negatively impacted by smoking.
# * **Oral exam column** has missing values or constant values and should be dropped or imputed.
# * **ID column** shows no meaningful correlation and should be dropped during modeling.

# %% [markdown]
# # Outliers Handling

# %%
#Creates a boxplot for all column using Seaborn's boxplot():
for col in numerical:
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
numeric_cols = ['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','eyesight(right)',
                'hearing(left)','hearing(right)','systolic','relaxation','fasting blood sugar',
                'Cholesterol','triglyceride','HDL','LDL','hemoglobin','Urine protein',
                'serum creatinine','AST','ALT','Gtp','dental caries']

# IQR Outlier Removal
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %%
for col in numerical:
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# # Model Training and Setup

# %% [markdown]
# ## Seperate Features and target

# %%
X = df.drop("smoking", axis=1)
y = df["smoking"]

# %% [markdown]
# ## Normalize the data

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Feature Selection (TOP 10)

# %%
selector = SelectKBest(score_func=f_classif, k=10)
X_selected = selector.fit_transform(X_scaled, y)
selected_features = X.columns[selector.get_support()]
print("Selected Features:", selected_features.tolist())
print("\n")
# Out:
# Selected Features: ['gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'triglyceride', 'HDL', 'hemoglobin', 'serum creatinine', 'Gtp']
# c:\Python-3.10\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [ 8  9 18 23 24] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# c:\Python-3.10\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.3, random_state=42)

# %%
treemodel= DecisionTreeClassifier(random_state=42)

# %%
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn import tree
plt.figure(figsize=(30,15))
tree.plot_tree(treemodel)
# Out:
# [Text(0.3139387604915618, 0.984375, 'x[0] <= -0.151\ngini = 0.418\nsamples = 17476\nvalue = [12269, 5207]'),
#  Text(0.09491665567185904, 0.953125, 'x[9] <= 0.255\ngini = 0.064\nsamples = 7448\nvalue = [7201.0, 247.0]'),
#  Text(0.05681434616603685, 0.921875, 'x[1] <= -1.825\ngini = 0.05\nsamples = 6400\nvalue = [6237, 163]'),
#  Text(0.04262058643418963, 0.890625, 'x[2] <= -0.458\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.042226696649475016, 0.859375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.043014476218904245, 0.859375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07100810589788407, 0.890625, 'x[5] <= 2.997\ngini = 0.049\nsamples = 6397\nvalue = [6236, 161]'),
#  Text(0.04380225578833348, 0.859375, 'x[9] <= -0.903\ngini = 0.048\nsamples = 6384\nvalue = [6226, 158]'),
#  Text(0.015029357098017011, 0.828125, 'x[4] <= 0.586\ngini = 0.024\nsamples = 2095\nvalue = [2070, 25]'),
# ...

# %%
y_pred=treemodel.predict(X_test)

# %%
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
score_dct = accuracy_score(y_pred,y_test)
print(score_dct)
# Out:
# 0.7868108396742758

# %%
classification_report(y_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.84      0.85      0.85      5184\n           1       0.66      0.64      0.65      2307\n\n    accuracy                           0.79      7491\n   macro avg       0.75      0.75      0.75      7491\nweighted avg       0.78      0.79      0.79      7491\n'

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=100),

    "Random Forest": RandomForestClassifier(random_state=42)
}

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8191162728607663

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.77459912890744

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[4655,  608],
#        [ 747, 1481]], dtype=int64)

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.86      0.88      0.87      5263\n           1       0.71      0.66      0.69      2228\n\n    accuracy                           0.82      7491\n   macro avg       0.79      0.77      0.78      7491\nweighted avg       0.82      0.82      0.82      7491\n'

# %%
plt.figure(figsize=(10, 8))

for name, model in models.items():
    y_pred_proba = model.predict_proba(X_test)[:, 1]  # probability of class 1
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()


for name, model in models.items():
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix - {name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()



results = []
for name, model in models.items():
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]
    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "ROC AUC": roc_auc_score(y_test, y_proba)
    })

results_df = pd.DataFrame(results)


results_df.set_index('Model')[['Accuracy', 'ROC AUC']].plot(kind='bar', figsize=(8, 5))
plt.title("Model Comparison: Accuracy & ROC AUC")
plt.ylabel("Score")
plt.ylim(0, 1.05)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# The Random Forest Classifier algorithm is better than the others in terms of both accuracy and ROC AUC
